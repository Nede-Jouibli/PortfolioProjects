# %% [markdown]
# ## Scrapping a product page from Amazon

# %% [markdown]
# - We will get the title and price from an Amazon page
# - Create a csv file to store the data
# - Automate the storing process
# - Send emails in case of a price drop

# %%
#importing libraries

from bs4 import BeautifulSoup
import requests
import time
import datetime
import smtplib

# %%
#Connect to Amazon

URL = 'https://www.amazon.com/Nikon-COOLPIX-Digital-Camera-Black/dp/B01C3LEBW6/ref=sr_1_10?crid=1K28XM4LGQDO&keywords=camera&qid=1666844318&qu=eyJxc2MiOiI4LjkxIiwicXNhIjoiOC42OSIsInFzcCI6IjguMTIifQ%3D%3D&sprefix=cam%2Caps%2C236&sr=8-10'

headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}

page = requests.get(URL, headers=headers)

soup1= BeautifulSoup(page.content, 'html.parser')
soup2= BeautifulSoup(soup1.prettify(), 'html.parser')

title = soup2.find(id='productTitle').get_text()
price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

print(title)
print(price)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">
#    Amazon.com
#   </title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
#Cleaning Data
price = price.strip()[1:]
title = title.strip()

# %%
import datetime

today=datetime.date.today()
print(today)

# %%
#Create a CSV file to store data
import csv

header = ['Title', 'Price', 'Date']
data = [title, price, today]

#with open('AmazonWebScraper.csv', 'w', newline='', encoding='UTF8') as f:
    #writer = csv.writer(f)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\ASUS\AmazonWebScraper.csv')

print(df)

# %%
#appending data to csv

with open('AmazonWebScraper.csv', 'a+', newline='', encoding='UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
#automating the appendingprocess

def check_price():
    URL = 'https://www.amazon.com/Nikon-COOLPIX-Digital-Camera-Black/dp/B01C3LEBW6/ref=sr_1_10?crid=1K28XM4LGQDO&keywords=camera&qid=1666844318&qu=eyJxc2MiOiI4LjkxIiwicXNhIjoiOC42OSIsInFzcCI6IjguMTIifQ%3D%3D&sprefix=cam%2Caps%2C236&sr=8-10'

    headers= {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36"}

    page = requests.get(URL, headers=headers)

    soup1= BeautifulSoup(page.content, 'html.parser')
    soup2= BeautifulSoup(soup1.prettify(), 'html.parser')

    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(id='corePriceDisplay_desktop_feature_div').get_text()

    price = price.strip()[1:]
    title = title.strip()

    import datetime

    today=datetime.date.today()
    print(today)
    import csv

    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    with open('AmazonWebScraper.csv', 'w', newline='', encoding='UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(header)
        writer.writerow(data)
    if(price < 100):
        send_mail()

# %%
#Checking the price daily
while(True):
    check_price()
    time.sleep(86400)

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\ASUS\AmazonWebScraper.csv')

print(df)

# %%
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('nede+amazon@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The camera you want is below $100! Buy it now!"
    body = "This is the moment we have been waiting for. Now is your chance to buy the camera you want."
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'nede+amazon@gmail.com',
        msg
     
    )
